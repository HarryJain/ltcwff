# %% [markdown]
# # Grade NBA Predictions

# %% [markdown]
# ### Module Imports

# %%
from os import path
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
from datetime import date

# %% [markdown]
# ### Global Variables and Settings

# %%
# Display all columns of DataFrames
pd.options.display.max_columns = None

# Print all output in a cell not just the last piece of output
InteractiveShell.ast_node_interactivity = "all"

# Location of sports data
DATA_DIR = 'C:\\Users\\Harry\\Documents\\LTCWFF\\ltcwff_files\\data'

# %% [markdown]
# ### Load Data

# %%
def load_data():
    # Load data from csv and reset the index
    game_data = pd.read_csv(path.join(DATA_DIR,'scraped_nba_combined_2021_compressed.csv'))
    game_data = game_data.set_index('Index')

    # Convert possible rows to numeric values
    for col in game_data.columns:
        try:
            game_data[col] = game_data.to_numeric(df[col])
        except:
            continue

    return game_data

# %%
game_data = load_data()

latest_date = str(game_data.loc[game_data.index[len(game_data.index) - 1], 'Date'])

year = int(latest_date[0:4])
month = int(latest_date[4:6])
day = int(latest_date[6:8])

toall = date.today()
toyear = int(toall.strftime("%Y"))
tomonth = int(toall.strftime("%m"))
today = int(toall.strftime("%d"))

if toyear >= year and (tomonth > month or (tomonth == month and today > day + 1)):
    os.system('python update_nba_boxscores_compressed.py')
    os.system('python update_nba_odds_compressed.py')
    os.system('python combine_boxscore_odds_compressed.py')

    game_data = load_data()

# %%
# # Days in each month
# days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]


# # Set today to yesterday
# if today == 1:
#     if tomonth == 1:
#         tomonth = 12
#         toyear -= 1
#     else:
#         tomonth -= 1
#     today = days[tomonth]
# else:
#     today -= 1


# # Allow date override
# date_input = input("Date to grade in YYYYMMDD format (press ENTER to default to yesterday)")

# if date_input != None and date_input != '' and not date_input.isspace():
#     year = date_input[0:4]
#     month = date_input[4:6]
#     day = date_input[6:8]
# else:
#     date_input = f'{toyear}{tomonth:02d}{today:02d}'

# date_input = int(date_input)
# date_input

# %%
predictions = pd.read_csv(path.join(DATA_DIR, f'daily_predictions\\daily_predictions.csv'))
predictions = predictions.set_index('Index')


# Update only ungraded predictions
inds = list(predictions.loc[predictions['Spread Correct'].isnull()].index)
# Update all prediction grades
#inds = list(predictions.index)
inds = [ind for ind in inds if ind in list(game_data.index)]

for ind in inds:
    spread = 'Home' if predictions.loc[ind, 'Spread Prediction'] == predictions.loc[ind, 'Home Team'] else 'Away'
    not_spread = 'Home' if spread != 'Home' else 'Away'
    if game_data.loc[ind, f'{spread} T'] - game_data.loc[ind, f'{not_spread} T'] > -predictions.loc[ind, f'{spread} Spread']:
        predictions.loc[ind, 'Spread Correct'] = 'Yes'
    else:
        predictions.loc[ind, 'Spread Correct'] = 'No'

    total = predictions.loc[ind, 'Total Prediction']
    if (total == 'Over' and game_data.loc[ind, 'Home T'] + game_data.loc[ind, 'Away T'] > predictions.loc[ind, 'Over']) or (total == 'Under' and game_data.loc[ind, 'Home T'] + game_data.loc[ind, 'Away T'] < predictions.loc[ind, 'Over']):
        predictions.loc[ind, 'Total Correct'] = 'Yes'
    else:
        predictions.loc[ind, 'Total Correct'] = 'No'

    ml = 'Home' if predictions.loc[ind, 'ML Prediction'] == predictions.loc[ind, 'Home Team'] else 'Away'
    not_ml = 'Home' if ml != 'Home' else 'Away'
    if game_data.loc[ind, f'{ml} T'] > game_data.loc[ind, f'{not_ml} T']:
        predictions.loc[ind, 'ML Correct'] = 'Yes'
    else:
        predictions.loc[ind, 'ML Correct'] = 'No'

predictions.style.apply(lambda y: ['background: green' if v == 'Yes' else 'background: red' if v == 'No' else '' for v in y], axis = 1, subset = ['Spread Correct', 'Total Correct', 'ML Correct'])

predictions.to_csv(path.join(DATA_DIR, f'daily_predictions\\daily_predictions.csv'))
# Out:
# <style  type="text/css" >
# #T_3d9b9_row0_col19,#T_3d9b9_row0_col20,#T_3d9b9_row0_col21,#T_3d9b9_row1_col20,#T_3d9b9_row3_col20,#T_3d9b9_row4_col19,#T_3d9b9_row4_col20,#T_3d9b9_row4_col21,#T_3d9b9_row7_col19,#T_3d9b9_row7_col20,#T_3d9b9_row7_col21,#T_3d9b9_row8_col20,#T_3d9b9_row9_col20,#T_3d9b9_row10_col20,#T_3d9b9_row11_col19,#T_3d9b9_row11_col20,#T_3d9b9_row11_col21,#T_3d9b9_row12_col19,#T_3d9b9_row12_col21,#T_3d9b9_row13_col20,#T_3d9b9_row14_col20,#T_3d9b9_row15_col20,#T_3d9b9_row16_col20,#T_3d9b9_row17_col19,#T_3d9b9_row17_col21,#T_3d9b9_row18_col20,#T_3d9b9_row19_col19,#T_3d9b9_row20_col19,#T_3d9b9_row20_col21,#T_3d9b9_row24_col19,#T_3d9b9_row25_col19,#T_3d9b9_row25_col20,#T_3d9b9_row26_col19,#T_3d9b9_row26_col21,#T_3d9b9_row27_col19,#T_3d9b9_row27_col20,#T_3d9b9_row27_col21,#T_3d9b9_row28_col19,#T_3d9b9_row28_col21,#T_3d9b9_row29_col19,#T_3d9b9_row29_col20,#T_3d9b9_row29_col21,#T_3d9b9_row31_col20,#T_3d9b9_row31_col21,#T_3d9b9_row32_col21,#T_3d9b9_row33_col19,#T_3d9b9_row33_col21,#T_3d9b9_row34_col20,#T_3d9b9_row35_col19,#T_3d9b9_row35_col21,#T_3d9b9_row36_col19,#T_3d9b9_row37_col20,#T_3d9b9_row38_col19,#T_3d9b9_row38_col21,#T_3d9b9_row39_col19,#T_3d9b9_row39_col20,#T_3d9b9_row39_col21,#T_3d9b9_row40_col19{
#             background:  red;
#         }#T_3d9b9_row1_col19,#T_3d9b9_row1_col21,#T_3d9b9_row2_col19,#T_3d9b9_row2_col20,#T_3d9b9_row2_col21,#T_3d9b9_row3_col19,#T_3d9b9_row3_col21,#T_3d9b9_row5_col19,#T_3d9b9_row5_col20,#T_3d9b9_row5_col21,#T_3d9b9_row6_col19,#T_3d9b9_row6_col20,#T_3d9b9_row6_col21,#T_3d9b9_row8_col19,#T_3d9b9_row8_col21,#T_3d9b9_row9_col19,#T_3d9b9_row9_col21,#T_3d9b9_row10_col19,#T_3d9b9_row10_col21,#T_3d9b9_row12_col20,#T_3d9b9_row13_col19,#T_3d9b9_row13_col21,#T_3d9b9_row14_col19,#T_3d9b9_row14_col21,#T_3d9b9_row15_col19,#T_3d9b9_row15_col21,#T_3d9b9_row16_col19,#T_3d9b9_row16_col21,#T_3d9b9_row17_col20,#T_3d9b9_row18_col19,#T_3d9b9_row18_col21,#T_3d9b9_row19_col20,#T_3d9b9_row19_col21,#T_3d9b9_row20_col20,#T_3d9b9_row21_col19,#T_3d9b9_row21_col20,#T_3d9b9_row21_col21,#T_3d9b9_row22_col19,#T_3d9b9_row22_col20,#T_3d9b9_row22_col21,#T_3d9b9_row23_col19,#T_3d9b9_row23_col20,#T_3d9b9_row23_col21,#T_3d9b9_row24_col20,#T_3d9b9_row24_col21,#T_3d9b9_row25_col21,#T_3d9b9_row26_col20,#T_3d9b9_row28_col20,#T_3d9b9_row30_col19,#T_3d9b9_row30_col20,#T_3d9b9_row30_col21,#T_3d9b9_row31_col19,#T_3d9b9_row32_col19,#T_3d9b9_row32_col20,#T_3d9b9_row33_col20,#T_3d9b9_row34_col19,#T_3d9b9_row34_col21,#T_3d9b9_row35_col20,#T_3d9b9_row36_col20,#T_3d9b9_row36_col21,#T_3d9b9_row37_col19,#T_3d9b9_row37_col21,#T_3d9b9_row38_col20,#T_3d9b9_row40_col20,#T_3d9b9_row40_col21{
#             background:  green;
#         }</style><table id="T_3d9b9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Home Team</th>        <th class="col_heading level0 col2" >Away Team</th>        <th class="col_heading level0 col3" >Home Spread</th>        <th class="col_heading level0 col4" >Home Spread Odds</th>        <th class="col_heading level0 col5" >Away Spread</th>        <th class="col_heading level0 col6" >Away Spread Odds</th>        <th class="col_heading level0 col7" >Home ML</th>        <th class="col_heading level0 col8" >Away ML</th>        <th class="col_heading level0 col9" >Over</th>        <th class="col_heading level0 col10" >Over Odds</th>        <th class="col_heading level0 col11" >Under</th>        <th class="col_heading level0 col12" >Under Odds</th>        <th class="col_heading level0 col13" >Spread Prediction</th>        <th class="col_heading level0 col14" >Spread Confidence</th>        <th class="col_heading level0 col15" >Total Prediction</th>        <th class="col_heading level0 col16" >Total Confidence</th>        <th class="col_heading level0 col17" >ML Prediction</th>        <th class="col_heading level0 col18" >ML Confidence</th>        <th class="col_heading level0 col19" >Spread Correct</th>        <th class="col_heading level0 col20" >Total Correct</th>        <th class="col_heading level0 col21" >ML Correct</th>    </tr>    <tr>        <th class="index_name level0" >Index</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d9b9_level0_row0" class="row_heading level0 row0" >20210223_ATL_CLE</th>
#                         <td id="T_3d9b9_row0_col0" class="data row0 col0" >20210223</td>
#                         <td id="T_3d9b9_row0_col1" class="data row0 col1" >ATL</td>
#                         <td id="T_3d9b9_row0_col2" class="data row0 col2" >CLE</td>
#                         <td id="T_3d9b9_row0_col3" class="data row0 col3" >-8.000000</td>
#                         <td id="T_3d9b9_row0_col4" class="data row0 col4" >-103.000000</td>
#                         <td id="T_3d9b9_row0_col5" class="data row0 col5" >8.000000</td>
#                         <td id="T_3d9b9_row0_col6" class="data row0 col6" >-107.000000</td>
#                         <td id="T_3d9b9_row0_col7" class="data row0 col7" >-315.000000</td>
#                         <td id="T_3d9b9_row0_col8" class="data row0 col8" >285.000000</td>
#                         <td id="T_3d9b9_row0_col9" class="data row0 col9" >228.000000</td>
#                         <td id="T_3d9b9_row0_col10" class="data row0 col10" >-108.000000</td>
#                         <td id="T_3d9b9_row0_col11" class="data row0 col11" >228.000000</td>
#                         <td id="T_3d9b9_row0_col12" class="data row0 col12" >-102.000000</td>
#                         <td id="T_3d9b9_row0_col13" class="data row0 col13" >ATL</td>
#                         <td id="T_3d9b9_row0_col14" class="data row0 col14" >4</td>
#                         <td id="T_3d9b9_row0_col15" class="data row0 col15" >Over</td>
#                         <td id="T_3d9b9_row0_col16" class="data row0 col16" >2</td>
#                         <td id="T_3d9b9_row0_col17" class="data row0 col17" >ATL</td>
#                         <td id="T_3d9b9_row0_col18" class="data row0 col18" >4</td>
#                         <td id="T_3d9b9_row0_col19" class="data row0 col19" >No</td>
#                         <td id="T_3d9b9_row0_col20" class="data row0 col20" >No</td>
#                         <td id="T_3d9b9_row0_col21" class="data row0 col21" >No</td>
#             </tr>
#             <tr>
#                         <th id="T_3d9b9_level0_row1" class="row_heading level0 row1" >20210223_DET_ORL</th>
#                         <td id="T_3d9b9_row1_col0" class="data row1 col0" >20210223</td>
#                         <td id="T_3d9b9_row1_col1" class="data row1 col1" >DET</td>
#                         <td id="T_3d9b9_row1_col2" class="data row1 col2" >ORL</td>
#                         <td id="T_3d9b9_row1_col3" class="data row1 col3" >4.500000</td>
#                         <td id="T_3d9b9_row1_col4" class="data row1 col4" >-107.000000</td>
#                         <td id="T_3d9b9_row1_col5" class="data row1 col5" >-4.500000</td>
#                         <td id="T_3d9b9_row1_col6" class="data row1 col6" >-103.000000</td>
#                         <td id="T_3d9b9_row1_col7" class="data row1 col7" >160.000000</td>
#                         <td id="T_3d9b9_row1_col8" class="data row1 col8" >-170.000000</td>
#                         <td id="T_3d9b9_row1_col9" class="data row1 col9" >211.000000

# %%
correction_cols = ['Spread Correct', 'Total Correct', 'ML Correct']
#correction_cols = ['Spread Correct', 'Total Correct']

correct = sum(predictions[correction_cols].isin(['Yes']).sum(axis = 0))
incorrect = sum(predictions[correction_cols].isin(['No']).sum(axis = 0))
total = len(predictions[correction_cols]) * len(correction_cols)

pd.DataFrame({'Correct': [correct], 'Incorrect': [incorrect], 'Total': [total], 'Percent Correct': [correct / total]})
# Out:
#    Correct  Incorrect  Total  Percent Correct
# 0       65         58    123         0.528455

# %%
predictions.loc[predictions['Date'] == 20210303].style.apply(lambda y: ['background: green' if v == 'Yes' else 'background: red' if v == 'No' else '' for v in y], axis = 1, subset = ['Spread Correct', 'Total Correct', 'ML Correct'])
# Out:
# <style  type="text/css" >
# #T_c1417_row0_col19,#T_c1417_row1_col19,#T_c1417_row1_col20,#T_c1417_row2_col20,#T_c1417_row3_col19,#T_c1417_row3_col21,#T_c1417_row4_col20,#T_c1417_row5_col20,#T_c1417_row5_col21,#T_c1417_row6_col19,#T_c1417_row6_col21,#T_c1417_row7_col20,#T_c1417_row9_col20,#T_c1417_row9_col21{
#             background:  green;
#         }#T_c1417_row0_col20,#T_c1417_row0_col21,#T_c1417_row1_col21,#T_c1417_row2_col19,#T_c1417_row2_col21,#T_c1417_row3_col20,#T_c1417_row4_col19,#T_c1417_row4_col21,#T_c1417_row5_col19,#T_c1417_row6_col20,#T_c1417_row7_col19,#T_c1417_row7_col21,#T_c1417_row8_col19,#T_c1417_row8_col20,#T_c1417_row8_col21,#T_c1417_row9_col19{
#             background:  red;
#         }</style><table id="T_c1417_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Home Team</th>        <th class="col_heading level0 col2" >Away Team</th>        <th class="col_heading level0 col3" >Home Spread</th>        <th class="col_heading level0 col4" >Home Spread Odds</th>        <th class="col_heading level0 col5" >Away Spread</th>        <th class="col_heading level0 col6" >Away Spread Odds</th>        <th class="col_heading level0 col7" >Home ML</th>        <th class="col_heading level0 col8" >Away ML</th>        <th class="col_heading level0 col9" >Over</th>        <th class="col_heading level0 col10" >Over Odds</th>        <th class="col_heading level0 col11" >Under</th>        <th class="col_heading level0 col12" >Under Odds</th>        <th class="col_heading level0 col13" >Spread Prediction</th>        <th class="col_heading level0 col14" >Spread Confidence</th>        <th class="col_heading level0 col15" >Total Prediction</th>        <th class="col_heading level0 col16" >Total Confidence</th>        <th class="col_heading level0 col17" >ML Prediction</th>        <th class="col_heading level0 col18" >ML Confidence</th>        <th class="col_heading level0 col19" >Spread Correct</th>        <th class="col_heading level0 col20" >Total Correct</th>        <th class="col_heading level0 col21" >ML Correct</th>    </tr>    <tr>        <th class="index_name level0" >Index</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1417_level0_row0" class="row_heading level0 row0" >20210303_DET_TOR</th>
#                         <td id="T_c1417_row0_col0" class="data row0 col0" >20210303</td>
#                         <td id="T_c1417_row0_col1" class="data row0 col1" >DET</td>
#                         <td id="T_c1417_row0_col2" class="data row0 col2" >TOR</td>
#                         <td id="T_c1417_row0_col3" class="data row0 col3" >7.500000</td>
#                         <td id="T_c1417_row0_col4" class="data row0 col4" >-105.000000</td>
#                         <td id="T_c1417_row0_col5" class="data row0 col5" >-7.500000</td>
#                         <td id="T_c1417_row0_col6" class="data row0 col6" >-105.000000</td>
#                         <td id="T_c1417_row0_col7" class="data row0 col7" >265.000000</td>
#                         <td id="T_c1417_row0_col8" class="data row0 col8" >-295.000000</td>
#                         <td id="T_c1417_row0_col9" class="data row0 col9" >210.500000</td>
#                         <td id="T_c1417_row0_col10" class="data row0 col10" >-105.000000</td>
#                         <td id="T_c1417_row0_col11" class="data row0 col11" >210.500000</td>
#                         <td id="T_c1417_row0_col12" class="data row0 col12" >-105.000000</td>
#                         <td id="T_c1417_row0_col13" class="data row0 col13" >DET</td>
#                         <td id="T_c1417_row0_col14" class="data row0 col14" >3</td>
#                         <td id="T_c1417_row0_col15" class="data row0 col15" >Under</td>
#                         <td id="T_c1417_row0_col16" class="data row0 col16" >3</td>
#                         <td id="T_c1417_row0_col17" class="data row0 col17" >TOR</td>
#                         <td id="T_c1417_row0_col18" class="data row0 col18" >3</td>
#                         <td id="T_c1417_row0_col19" class="data row0 col19" >Yes</td>
#                         <td id="T_c1417_row0_col20" class="data row0 col20" >No</td>
#                         <td id="T_c1417_row0_col21" class="data row0 col21" >No</td>
#             </tr>
#             <tr>
#                         <th id="T_c1417_level0_row1" class="row_heading level0 row1" >20210303_IND_CLE</th>
#                         <td id="T_c1417_row1_col0" class="data row1 col0" >20210303</td>
#                         <td id="T_c1417_row1_col1" class="data row1 col1" >IND</td>
#                         <td id="T_c1417_row1_col2" class="data row1 col2" >CLE</td>
#                         <td id="T_c1417_row1_col3" class="data row1 col3" >-7.000000</td>
#                         <td id="T_c1417_row1_col4" class="data row1 col4" >-105.000000</td>
#                         <td id="T_c1417_row1_col5" class="data row1 col5" >7.000000</td>
#                         <td id="T_c1417_row1_col6" class="data row1 col6" >-105.000000</td>
#                         <td id="T_c1417_row1_col7" class="data row1 col7" >-250.000000</td>
#                         <td id="T_c1417_row1_col8" class="data row1 col8" >230.000000</td>
#                         <td id="T_c1417_row1_col9" class="data row1 col9" >219.000000</td>
#                         <td id="T_c1417_row1_col10" class="data row1 col10" >-105.000000</td>
#                         <td id="T_c1417_row1_col11" class="data row1 col11" >219.000000</td>
#                         <td id="T_c1417_row1_col12" class="data row1 col12" >-105.000000</td>
#                         <td id="T_c1417_row1_col13" class="data row1 col13" >CLE</td>
#                         <td id="T_c1417_row1_col14" class="data row1 col14" >3</td>
#                         <td id="T_c1417_row1_col15" class="data row1 col15" >Over</td>
#                         <td id="T_c1417_row1_col16" class="data row1 col16" >4</td>
#                         <td id="T_c1417_row1_col17" class="data row1 col17" >CLE</td>
#                         <td id="T_c1417_row1_col18" class="data row1 col18" >1</td>
#                         <td id="T_c1417_row1_col19" class="data row1 col19" >Yes</td>
#                         <td id="T_c1417_row1_col20" class="data row1 col20" >Yes</td>
#                         <td id="T_c1417_row1_col21" class="data row1 col21" >No</td>
#             </tr>
#             <tr>
#                         <th id="T_c1417_level0_row2" class="row_heading level0 row2" >20210303_UTA_PHI</th>
#                         <td id="T_c1417_row2_col0" class="data row2 col0" >20210303</td>
#                         <td id="T_c1417_row2_col1" class="data row2 col1" >UTA</td>
#                         <td id="T_c1417_row2_col2" class="data row2 col2" >PHI</td>
#                         <td id="T_c1417_row2_col3" class="data row2 col3" >-3.500000</td>
#                         <td id="T_c1417_row2_col4" class="data row2 col4" >-103.000000</td>
#                         <td id="T_c1417_row2_col5" class="data row2 col5" >3.500000</td>
#                         <td id="T_c1417_row2_col6" class="data row2 col6" >-107.000000</td>
#                         <td id="T_c1417_row2_col7" class="data row2 col7" >-150.000000</td>
#                         <td id="T_c1417_r
