# %%
# Module Imports
import pandas as pd
import sqlite3
import os
from os import path
from datetime import date
from IPython.core.interactiveshell import InteractiveShell

# %%
# Display all columns of DataFrames
pd.options.display.max_columns = None

# Print all output in a cell not just the last piece of output
InteractiveShell.ast_node_interactivity = "all"

# Data directory for csv files
DATA_DIR = 'C:\\Users\\Harry\\Documents\\LTCWFF\\ltcwff_files\\data'

# Dictionary relating prop names to stats
stat_dict = {'Points': 'PTS', 'Assists': 'AST', 'Rebounds': 'TRB', 'Reb + Ast': 'TRB + AST', 'Made Threes': '3P', 'Pts + Ast': 'PTS + AST', 'Pts + Reb': 'PTS + TRB', 'Pts + Reb + Ast': 'PTS + TRB + AST'}

# Open database connection
conn = sqlite3.connect(path.join(DATA_DIR, 'nba.sqlite'))

# %%
# Get today's date in our format and print it out
today = date.today()
datef = today.strftime("%Y%m%d")
print(datef)

# Load prop data for today into a DataFrame
try:
    props_df = pd.read_csv(path.join(DATA_DIR, 'player_props', f'{datef} - new.csv'))
except:
    os.system('python new_get_player_props.py')
    props_df = pd.read_csv(path.join(DATA_DIR, f'{datef} - new.csv'))

# Clean prop table by dropping old index column and converting columns to numeric
props_df = props_df.drop(props_df.columns[0], axis = 1)
for col in props_df.columns:
    try:
        props_df[col] = pd.to_numeric(props_df[col])
    except:
        continue
props_df
# Out:
# 20210720
#        Player             Prop  Over  Over Odds  Under  Under Odds
# 0   bookede01           Points  31.5       -110   31.5        -110
# 1    paulch01           Points  21.5       -104   21.5        -116
# 2   aytonde01           Points  16.5       -110   16.5        -110
# 3   bridgmi01           Points  11.5        104   11.5        -126
# 4   crowdja01           Points  10.5       -118   10.5        -104
# ..        ...              ...   ...        ...    ...         ...
# 80  antetgi01  Pts + Reb + Ast  51.5       -122   51.5        -104
# 81  middlkh01  Pts + Reb + Ast  38.5       -106   38.5        -120
# 82  holidjr01  Pts + Reb + Ast  33.5       -108   33.5        -118
# 83  lopezbr01  Pts + Reb + Ast  16.5       -113   16.5        -113
# 84  tuckepj01  Pts + Reb + Ast  10.5       -104   10.5        -122
#
# [85 rows x 6 columns]

# %%
# Loop through each row of the props DataFrame
for ind in props_df.index:
    # Get the prop name to use in the query as well as the player name
    prop_parts = stat_dict[props_df.loc[ind, 'Prop']].split(' + ')
    prop_name = f'''"{'" + "'.join(prop_parts)}"'''
    player = props_df.loc[ind, 'Player']
    
    # Get the player's table for that prop
    table = pd.read_sql(f'''SELECT {prop_name} FROM player_games JOIN games ON player_games.game_id = games.game_id WHERE player_id = "{player}" AND Season = "2020-21" AND Playoffs = 1''', conn)
    for col in table.columns:
        try:
            table[col] = pd.to_numeric(table[col], errors='coerce')
        except:
            continue
    
    # Reset the prop name for single props
    if len(prop_parts) == 1:
        prop_name = prop_name[1:len(prop_name) - 1]
    
    # Create average and cover columns
    props_df.loc[ind, 'Playoff Avg'] = table[prop_name].mean()
    props_df.loc[ind, 'Finals Avg'] = table[-5:][prop_name].mean()
    props_df.loc[ind, 'Playoff Cover %'] = (table[prop_name] > props_df.loc[ind, 'Over']).mean()
    props_df.loc[ind, 'Finals Cover %'] = (table.iloc[-5:][prop_name] > props_df.loc[ind, 'Over']).mean()

# %%
# Print whole props table and highlight over/under cover percentages
props_df.style.apply(lambda x: [ "background: green" if v >= 0.5 else "background: red" for v in x ], axis = 1, subset = ['Playoff Cover %', 'Finals Cover %'])
# Out:
# <style  type="text/css" >
# #T_cb78f_row0_col8,#T_cb78f_row0_col9,#T_cb78f_row1_col8,#T_cb78f_row1_col9,#T_cb78f_row3_col8,#T_cb78f_row4_col8,#T_cb78f_row5_col8,#T_cb78f_row5_col9,#T_cb78f_row6_col8,#T_cb78f_row7_col8,#T_cb78f_row7_col9,#T_cb78f_row8_col9,#T_cb78f_row9_col8,#T_cb78f_row10_col8,#T_cb78f_row11_col9,#T_cb78f_row13_col9,#T_cb78f_row14_col8,#T_cb78f_row14_col9,#T_cb78f_row15_col8,#T_cb78f_row15_col9,#T_cb78f_row16_col8,#T_cb78f_row16_col9,#T_cb78f_row17_col8,#T_cb78f_row18_col8,#T_cb78f_row18_col9,#T_cb78f_row19_col8,#T_cb78f_row19_col9,#T_cb78f_row20_col8,#T_cb78f_row20_col9,#T_cb78f_row22_col9,#T_cb78f_row23_col8,#T_cb78f_row24_col8,#T_cb78f_row24_col9,#T_cb78f_row25_col8,#T_cb78f_row25_col9,#T_cb78f_row26_col8,#T_cb78f_row26_col9,#T_cb78f_row27_col8,#T_cb78f_row27_col9,#T_cb78f_row28_col8,#T_cb78f_row28_col9,#T_cb78f_row30_col8,#T_cb78f_row31_col8,#T_cb78f_row31_col9,#T_cb78f_row33_col8,#T_cb78f_row33_col9,#T_cb78f_row34_col8,#T_cb78f_row34_col9,#T_cb78f_row35_col8,#T_cb78f_row38_col8,#T_cb78f_row38_col9,#T_cb78f_row40_col8,#T_cb78f_row40_col9,#T_cb78f_row44_col8,#T_cb78f_row45_col8,#T_cb78f_row48_col8,#T_cb78f_row49_col8,#T_cb78f_row49_col9,#T_cb78f_row50_col8,#T_cb78f_row51_col8,#T_cb78f_row51_col9,#T_cb78f_row52_col9,#T_cb78f_row54_col8,#T_cb78f_row54_col9,#T_cb78f_row55_col8,#T_cb78f_row55_col9,#T_cb78f_row56_col8,#T_cb78f_row56_col9,#T_cb78f_row57_col8,#T_cb78f_row57_col9,#T_cb78f_row58_col8,#T_cb78f_row59_col8,#T_cb78f_row59_col9,#T_cb78f_row60_col8,#T_cb78f_row61_col8,#T_cb78f_row61_col9,#T_cb78f_row62_col9,#T_cb78f_row64_col8,#T_cb78f_row65_col9,#T_cb78f_row66_col8,#T_cb78f_row66_col9,#T_cb78f_row67_col8,#T_cb78f_row68_col8,#T_cb78f_row68_col9,#T_cb78f_row69_col8,#T_cb78f_row70_col8,#T_cb78f_row71_col9,#T_cb78f_row74_col8,#T_cb78f_row74_col9,#T_cb78f_row75_col8,#T_cb78f_row76_col8,#T_cb78f_row76_col9,#T_cb78f_row77_col8,#T_cb78f_row77_col9,#T_cb78f_row78_col8,#T_cb78f_row78_col9,#T_cb78f_row79_col8,#T_cb78f_row80_col8,#T_cb78f_row80_col9,#T_cb78f_row81_col8,#T_cb78f_row82_col8,#T_cb78f_row82_col9,#T_cb78f_row83_col9{
#             background:  red;
#         }#T_cb78f_row2_col8,#T_cb78f_row2_col9,#T_cb78f_row3_col9,#T_cb78f_row4_col9,#T_cb78f_row6_col9,#T_cb78f_row8_col8,#T_cb78f_row9_col9,#T_cb78f_row10_col9,#T_cb78f_row11_col8,#T_cb78f_row12_col8,#T_cb78f_row12_col9,#T_cb78f_row13_col8,#T_cb78f_row17_col9,#T_cb78f_row21_col8,#T_cb78f_row21_col9,#T_cb78f_row22_col8,#T_cb78f_row23_col9,#T_cb78f_row29_col8,#T_cb78f_row29_col9,#T_cb78f_row30_col9,#T_cb78f_row32_col8,#T_cb78f_row32_col9,#T_cb78f_row35_col9,#T_cb78f_row36_col8,#T_cb78f_row36_col9,#T_cb78f_row37_col8,#T_cb78f_row37_col9,#T_cb78f_row39_col8,#T_cb78f_row39_col9,#T_cb78f_row41_col8,#T_cb78f_row41_col9,#T_cb78f_row42_col8,#T_cb78f_row42_col9,#T_cb78f_row43_col8,#T_cb78f_row43_col9,#T_cb78f_row44_col9,#T_cb78f_row45_col9,#T_cb78f_row46_col8,#T_cb78f_row46_col9,#T_cb78f_row47_col8,#T_cb78f_row47_col9,#T_cb78f_row48_col9,#T_cb78f_row50_col9,#T_cb78f_row52_col8,#T_cb78f_row53_col8,#T_cb78f_row53_col9,#T_cb78f_row58_col9,#T_cb78f_row60_col9,#T_cb78f_row62_col8,#T_cb78f_row63_col8,#T_cb78f_row63_col9,#T_cb78f_row64_col9,#T_cb78f_row65_col8,#T_cb78f_row67_col9,#T_cb78f_row69_col9,#T_cb78f_row70_col9,#T_cb78f_row71_col8,#T_cb78f_row72_col8,#T_cb78f_row72_col9,#T_cb78f_row73_col8,#T_cb78f_row73_col9,#T_cb78f_row75_col9,#T_cb78f_row79_col9,#T_cb78f_row81_col9,#T_cb78f_row83_col8,#T_cb78f_row84_col8,#T_cb78f_row84_col9{
#             background:  green;
#         }</style><table id="T_cb78f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Player</th>        <th class="col_heading level0 col1" >Prop</th>        <th class="col_heading level0 col2" >Over</th>        <th class="col_heading level0 col3" >Over Odds</th>        <th class="col_heading level0 col4" >Under</th>        <th class="col_heading level0 col5" >Under Odds</th>        <th class="col_heading level0 col6" >Playoff Avg</th>        <th class="col_heading level0 col7" >Finals Avg</th>        <th class="col_heading level0 col8" >Playoff Cover %</th>        <th class="col_heading level0 col9" >Finals Cover %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cb78f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cb78f_row0_col0" class="data row0 col0" >bookede01</td>
#                         <td id="T_cb78f_row0_col1" class="data row0 col1" >Points</td>
#                         <td id="T_cb78f_row0_col2" class="data row0 col2" >31.500000</td>
#                         <td id="T_cb78f_row0_col3" class="data row0 col3" >-110</td>
#                         <td id="T_cb78f_row0_col4" class="data row0 col4" >31.500000</td>
#                         <td id="T_cb78f_row0_col5" class="data row0 col5" >-110</td>
#                         <td id="T_cb78f_row0_col6" class="data row0 col6" >27.714286</td>
#                         <td id="T_cb78f_row0_col7" class="data row0 col7" >30.000000</td>
#                         <td id="T_cb78f_row0_col8" class="data row0 col8" >0.285714</td>
#                         <td id="T_cb78f_row0_col9" class="data row0 col9" >0.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_cb78f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cb78f_row1_col0" class="data row1 col0" >paulch01</td>
#                         <td id="T_cb78f_row1_col1" class="data row1 col1" >Points</td>
#                         <td id="T_cb78f_row1_col2" class="data row1 col2" >21.500000</td>
#                         <td id="T_cb78f_row1_col3" class="data row1 col3" >-104</td>
#                         <td id="T_cb78f_row1_col4" class="data row1 col4" >21.500000</td>
#                         <td id="T_cb78f_row1_col5" class="data row1 col5" >-116</td>
#                         <td id="T_cb78f_row1_col6" class="data row1 col6" >18.842105</td>
#                         <td id="T_cb78f_row1_col7" class="data row1 col7" >21.000000</td>
#                         <td id="T_cb78f_row1_col8" class="data row1 col8" >0.315789</td>
#                         <td id="T_cb78f_row1_col9" class="data row1 col9" >0.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_cb78f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cb78f_row2_col0" class="data row2 col0" >aytonde01</td>
#                         <td id="T_cb78f_row2_col1" class="data row2 col1" >Points</td>
#                         <td id="T_cb78f_row2_col2" class="data row2 col2" >16.500000</td>
#                         <td id="T_cb78f_row2_col3" class="data row2 col3" >-110</td>
#                         <td id="T_cb78f_row2_col4" class="data row2 col4" >16.500000</td>
#                         <td id="T_cb78f_row2_col5" class="data row2 col5" >-110</td>
#                         <td id="T_cb78f_row2_col6" class="data row2 col6" >15.952381</td>
#                         <td id="T_cb78f_row2_col7" class="data row2 col7" >15.200000</td>
#                         <td id="T_cb78f_row2_col8" class="data row2 col8" >0.523810</td>
#                         <td id="T_cb78f_row2_col9" class="data row2 col9" >0.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_cb78f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cb78f_row3_col0" class="data row3 col0" >bridgmi01</td>
#                         <td id="T_cb78f_row3_col1" class="data row3 col1" >Points</td>
#                         <td id="T_cb78f_row3_col2" class="data row3 col2" >11.500000</td>
#                         <td id="T_cb78f_row3_col3" class="data row3 col3" >104</td>
#                         <td id="T_cb78f_row3_col4" class="data row3 col4" >11.500000</td>
#                         <td id="T_cb78f_row3_col5" class="data row3 col5" >-126</td>
#                         <td id="T_cb78f_row3_col6" class="data row3 col6" >11.285714</td>
#                         <td id="T_cb78f_row3_co

# %%
# Print the extreme cover values
props_df[(props_df['Playoff Cover %'] > 0.5) & (props_df['Finals Cover %'] > 0.5)].sort_values(by = ['Playoff Cover %'], ascending = False)
props_df[(props_df['Finals Cover %'] > 0.5)]
# Out:
#        Player             Prop  Over  Over Odds  Under  Under Odds  \
# 21  lopezbr01         Rebounds   4.5       -132    4.5         108
# 72  holidjr01        Reb + Ast  13.5       -102   13.5        -125
# 12  payneca01           Points   6.5        102    6.5        -126
# 32  holidjr01          Assists   7.5       -144    7.5         118
# 39  middlkh01      Made Threes   2.5       -150    2.5         118
# 42  tuckepj01      Made Threes   0.5       -265    0.5         200
# 73  lopezbr01        Reb + Ast   5.5        110    5.5        -140
# 41  lopezbr01      Made Threes   0.5       -245    0.5         186
# 29  crowdja01          Assists   1.5       -124    1.5         102
# 36  bridgmi01      Made Threes   1.5       -162    1.5         126
# 37  crowdja01      Made Threes   2.5       -138    2.5         108
# 63  tuckepj01        Pts + Reb   9.5        102    9.5        -130
# 84  tuckepj01  Pts + Reb + Ast  10.5       -104   10.5        -122
# 2   aytonde01           Points  16.5       -110   16.5        -110
# 46  aytonde01        Pts + Ast  17.5       -128   17.5         100
# 47  bridgmi01        Pts + Ast  12.5       -120   12.5        -106
#
#     Playoff Avg  Finals Avg  Playoff Cover %  Finals Cover %
# 21     5.772727         4.8         0.772727             0.6
# 72    14.136364        14.6         0.681818             0.8
# 12     9.285714         6.8         0.666667             0.6
# 32     8.545455         9.0         0.636364             0.6
# 39     2.681818         3.0         0.636364             0.8
# 42     0.863636         0.8         0.636364             0.8
# 73     6.045455         5.0         0.636364             0.6
# 41     1.045455         1.0         0.590909             0.6
# 29     1.952381         2.0         0.571429             0.6
# 36     1.666667         1.8         0.571429             0.6
# 37     2.476190         2.8         0.571429             0.6
# 63     9.227273         8.2         0.545455             0.6
# 84    10.318182         9.4         0.545455             0.6
# 2     15.952381        15.2         0.523810             0.6
# 46    17.095238        17.2         0.523810             0.6
# 47    12.904762        14.0         0.523810             0.6
#        Player             Prop  Over  Over Odds  Under  Under Odds  \
# 2   aytonde01           Points  16.5       -110   16.5        -110
# 3   bridgmi01           Points  11.5        104   11.5        -126
# 4   crowdja01           Points  10.5       -118   10.5        -104
# 6   middlkh01           Points  25.5       -110   25.5        -110
# 9   tuckepj01           Points   4.5       -104    4.5        -118
# 10  connapa01           Points   8.5       -108    8.5        -114
# 12  payneca01           Points   6.5        102    6.5        -126
# 17  crowdja01         Rebounds   6.5       -114    6.5        -106
# 21  lopezbr01         Rebounds   4.5       -132    4.5         108
# 23  connapa01         Rebounds   4.5       -142    4.5         116
# 29  crowdja01          Assists   1.5       -124    1.5         102
# 30  antetgi01          Assists   5.5       -128    5.5         104
# 32  holidjr01          Assists   7.5       -144    7.5         118
# 35   paulch01      Made Threes   1.5       -200    1.5         154
# 36  bridgmi01      Made Threes   1.5       -162    1.5         126
# 37  crowdja01      Made Threes   2.5       -138    2.5         108
# 39  middlkh01      Made Threes   2.5       -150    2.5         118
# 41  lopezbr01      Made Threes   0.5       -245    0.5         186
# 42  tuckepj01      Made Threes   0.5       -265    0.5         200
# 43  connapa01      Made Threes   1.5       -150    1.5         118
# 44  bookede01        Pts + Ast  35.5       -122   35.5        -104
# 45   paulch01        Pts + Ast  30.5       -111   30.5        -115
# 46  aytonde01        Pts + Ast  17.5       -128   17.5         100
# 47  bridgmi01        Pts + Ast  12.5       -120   12.5        -106
# 48  crowdja01        Pts + Ast  12.5       -115   12.5        -111
# 50  middlkh01        Pts + Ast  30.5       -125   30.5        -102
# 53  tuckepj01        Pts + Ast   5.5       -118    5.5        -108
# 58  crowdja01        Pts + Reb  17.5       -118   17.5        -108
# 60  middlkh01        Pts + Reb  32.5       -122   32.5        -104
# 63  tuckepj01        Pts + Reb   9.5        102    9.5        -130
# 64  connapa01        Pts + Reb  13.5       -118   13.5        -108
# 67  aytonde01        Reb + Ast  13.5       -136   13.5         106
# 69  crowdja01        Reb + Ast   8.5       -111    8.5        -115
# 70  antetgi01        Reb + Ast  18.5       -130   18.5         102
# 72  holidjr01        Reb + Ast  13.5       -102   13.5        -125
# 73  lopezbr01        Reb + Ast   5.5        110    5.5        -140
# 75  bookede01  Pts + Reb + Ast  41.5       -104   41.5        -122
# 79  crowdja01  Pts + Reb + Ast  19.5       -113   19.5        -113
# 81  middlkh01  Pts + Reb + Ast  38.5       -106   38.5        -120
# 84  tuckepj01  Pts + Reb + Ast  10.5       -104   10.5        -122
#
#     Playoff Avg  Finals Avg  Playoff Cover %  Finals Cover %
# 2     15.952381        15.2         0.523810             0.6
# 3     11.285714        13.0         0.428571             0.6
# 4     10.571429        11.0         0.476190             0.6
# 6     23.863636        25.4         0.409091             0.6
# 9      4.454545         4.8         0.454545             0.6
# 10     7.181818        11.0         0.454545             0.6
# 12     9.285714         6.8         0.666667             0.6
# 17     5.761905         7.6         0.333333             0.6
# 21     5.772727         4.8         0.772727             0.6
# 23     4.227273         5.4         0.363636             0.6
# 29     1.952381         2.0         0.571429             0.6
# 30     5.300000         5.6         0.350000             0.6
# 32     8.545455         9.0         0.636364             0.6
# 35     1.473684         2.2         0.421053             0.6
# 36     1.666667         1.8         0.571429             0.6
# 37     2.476190         2.8         0.571429             0.6
# 39     2.681818         3.0         0.636364             0.8
# 41     1.045455         1.0         0.590909             0.6
# 42     0.863636         0.8         0.636364             0.8
# 43     1.681818         3.0         0.500000             1.0
# 44    32.238095        33.8         0.333333             0.6
# 45    27.578947        29.8         0.421053             0.6
# 46    17.095238        17.2         0.523810             0.6
# 47    12.904762        14.0         0.523810             0.6
# 48    12.523810        13.0         0.476190             0.8
# 50    29.000000        30.8         0.409091             0.6
# 53     5.545455         6.0         0.500000             0.6
# 58    16.333333        18.6         0.428571             0.6
# 60    31.545455        32.0         0.454545             0.6
# 63     9.227273         8.2         0.545455             0.6
# 64    11.409091        16.4         0.272727             0.6
# 67    13.238095        15.2         0.428571             0.6
# 69     7.714286         9.6         0.285714             0.6
# 70    18.050000        18.6         0.450000             0.6
# 72    14.136364        14.6         0.681818             0.8
# 73     6.045455         5.0         0.636364             0.6
# 75    38.000000        37.4         0.380952             0.6
# 79    18.285714        20.6         0.476190             0.6
# 81    36.681818        37.4         0.454545             0.6
# 84    10.318182         9.4         0.545455             0.6
